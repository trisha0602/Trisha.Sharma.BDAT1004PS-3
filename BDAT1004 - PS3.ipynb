# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Question 1

# %% [markdown]
# Occupations

# %% [markdown]
# #### Step 1. Import the necessary libraries

# %% [markdown]
# import numpy as np
# import pandas as pd

# %% [markdown]
# #### Step 2. Import the dataset from this address

# %%
dataset = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"

# %% [markdown]
# #### Step 3. Assign it to a variable called users

# %%
users = pd.read_csv(dataset,sep="|")
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# #### Step 4. Discover what is the mean age per occupation

# %%
users.groupby(['occupation'])['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# #### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
GenderOccupation = users.groupby(['occupation', 'gender']).gender.count()
GenderOccupation
# Out:
# occupation     gender
# administrator  F          36
#                M          43
# artist         F          13
#                M          15
# doctor         M           7
# educator       F          26
#                M          69
# engineer       F           2
#                M          65
# entertainment  F           2
#                M          16
# executive      F           3
#                M          29
# healthcare     F          11
#                M           5
# homemaker      F           6
#                M           1
# lawyer         F           2
#                M          10
# librarian      F          29
#                M          22
# marketing      F          10
#                M          16
# none           F           4
#                M           5
# other          F          36
#                M          69
# programmer     F           6
#                M          60
# retired        F           1
#                M          13
# ...

# %%
total = users.groupby('gender').gender.count()
total
# Out:
# gender
# F    273
# M    670
# Name: gender, dtype: int64

# %%
ratio=GenderOccupation /total
#ratio

# %%
ratio.xs('M', level=1).sort_values(ascending=False)  #xs() gets values at specified gender index and level
# Out:
# occupation
# student          0.202985
# other            0.102985
# educator         0.102985
# engineer         0.097015
# programmer       0.089552
# administrator    0.064179
# executive        0.043284
# scientist        0.041791
# technician       0.038806
# writer           0.038806
# librarian        0.032836
# marketing        0.023881
# entertainment    0.023881
# artist           0.022388
# retired          0.019403
# lawyer           0.014925
# salesman         0.013433
# doctor           0.010448
# none             0.007463
# healthcare       0.007463
# homemaker        0.001493
# Name: gender, dtype: float64

# %% [markdown]
# #### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').min('age') #minimum age per occupation
# Out:
#                user_id  age
# occupation
# administrator        7   21
# artist              23   19
# doctor             138   28
# educator            13   23
# engineer            25   22
# entertainment       16   15
# executive            6   22
# healthcare          60   22
# homemaker           20   20
# lawyer              10   21
# librarian           19   23
# marketing           46   24
# none                57   11
# other                2   13
# programmer          17   20
# retired            106   51
# salesman           112   18
# scientist           14   23
# student              9    7
# technician           1   21
# writer               3   18

# %%
users.groupby('occupation').max('age') #maximum age per occupation
# Out:
#                user_id  age
# occupation
# administrator      940   70
# artist             920   48
# doctor             935   64
# educator           937   63
# engineer           934   70
# entertainment      926   50
# executive          901   69
# healthcare         910   62
# homemaker          898   50
# lawyer             846   53
# librarian          942   69
# marketing          881   55
# none               756   55
# other              936   64
# programmer         927   63
# retired            900   73
# salesman           925   66
# scientist          930   55
# student            943   42
# technician         938   55
# writer             911   60

# %% [markdown]
# #### Step 7. For each combination of occupation and sex, calculate the mean age

# %%
users.groupby(['occupation','gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# #### Step 8. For each occupation present the percentage of women and men

# %%
TotalOccupation = users.groupby('occupation').gender.count()

# %%
percentage = (GenderOccupation/TotalOccupation)*100
percentage
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %% [markdown]
# # Question 2

# %% [markdown]
# Euro Teams

# %% [markdown]
# #### Step 1.  Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Step 2. Import the dataset from this address

# %%
dataset2 = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"

# %% [markdown]
# #### Step 3. Assign it to a variable called euro12

# %%
euro12 = pd.read_csv(dataset2,sep=",")
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### Step 4. Select only the Goal column

# %%
euro12[['Goals']]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %% [markdown]
# #### Step 5. How many team participated in the Euro2012?

# %%
euro12['Team'].count()
# Out:
# 16

# %% [markdown]
# #### Step 6. What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# #### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = pd.DataFrame(euro12[['Team','Yellow Cards','Red Cards']])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# #### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by = "Red Cards")    #sort by Red cards
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1

# %%
discipline.sort_values(by = "Yellow Cards")    #sort by Yellow cards
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 9                Poland             7          1
# 14               Sweden             7          0
# 0               Croatia             9          0
# 6                Greece             9          1
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0

# %% [markdown]
# #### Step 9. Calculate the mean Yellow Cards given per Team

# %%
discipline["Yellow Cards"].mean()
# Out:
# 7.4375

# %% [markdown]
# #### Step 10. Filter teams that scored more than 6 goals

# %%
euro12[['Team','Goals']][euro12.Goals>6]
# Out:
#        Team  Goals
# 5   Germany     10
# 13    Spain     12

# %% [markdown]
# #### Step 11. Select the teams that start with G

# %%
euro12[['Team']][euro12.Team.str[0]=='G']
# Out:
#       Team
# 5  Germany
# 6   Greece

# %% [markdown]
# #### Step 12. . Select the first 7 columns

# %%
euro12.iloc[:,0:7]     #source: https://www.kdnuggets.com/
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### Step 13. Select all columns except the last 3

# %%
euro12.iloc[:,:-3]   #source: https://www.codegrepper.com
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
accuracy = euro12.loc[:,['Team','Shooting Accuracy']]
filter = accuracy.loc[(accuracy["Team"]=='England')|(accuracy["Team"]=='Italy')|(accuracy["Team"]=='Russia') ,:]    #source:https://pandas.pydata.org
filter
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3

# %% [markdown]
# Housing

# %% [markdown]
# #### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Step 2. Create 3 differents Series, each of length 100, as follows:

# %% [markdown]
# The first a random number from 1 to 4

# %%
series1 = pd.Series(np.random.randint(1,5, size=100))
series1
# Out:
# 0     4
# 1     2
# 2     1
# 3     3
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    4
# 99    2
# Length: 100, dtype: int32

# %% [markdown]
# The second a random number from 1 to 3

# %%
series2 = pd.Series(np.random.randint(1,4, size=100))
series2
# Out:
# 0     2
# 1     3
# 2     3
# 3     3
# 4     1
#      ..
# 95    3
# 96    3
# 97    3
# 98    1
# 99    1
# Length: 100, dtype: int32

# %% [markdown]
# The third a random number from 10,000 to 30,000

# %%
series3 = pd.Series(np.random.randint(10000,30001, size=100))
series3
# Out:
# 0     16564
# 1     13136
# 2     10105
# 3     10969
# 4     26330
#       ...
# 95    26810
# 96    27676
# 97    13825
# 98    18073
# 99    26484
# Length: 100, dtype: int32

# %% [markdown]
# #### Step 3. Create a DataFrame by joinning the Series by column

# %%
dataframe = pd.concat([series1,series2,series3],axis=1)
dataframe
# Out:
#     0  1      2
# 0   4  2  16564
# 1   2  3  13136
# 2   1  3  10105
# 3   3  3  10969
# 4   1  1  26330
# .. .. ..    ...
# 95  1  3  26810
# 96  1  3  27676
# 97  1  3  13825
# 98  4  1  18073
# 99  2  1  26484
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df=dataframe.rename(columns={0:'bedrs',1:'bathrs',2:'price_sqr_meter'})
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       4       2            16564
# 1       2       3            13136
# 2       1       3            10105
# 3       3       3            10969
# 4       1       1            26330
# ..    ...     ...              ...
# 95      1       3            26810
# 96      1       3            27676
# 97      1       3            13825
# 98      4       1            18073
# 99      2       1            26484
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.concat([df.bedrs,df.bathrs,df.price_sqr_meter])
bigcolumn
# Out:
# 0         4
# 1         2
# 2         1
# 3         3
# 4         1
#       ...
# 95    26810
# 96    27676
# 97    13825
# 98    18073
# 99    26484
# Length: 300, dtype: int32

# %% [markdown]
# #### Step 6. Ops it seems it is going only until index 99. Is it true?

# %% [markdown]
# Yes, index is until 99 as shown above.

# %% [markdown]
# #### Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index(drop=True, inplace=True)   #source: https://pandas.pydata.org
bigcolumn
# Out:
# 0          4
# 1          2
# 2          1
# 3          3
# 4          1
#        ...
# 295    26810
# 296    27676
# 297    13825
# 298    18073
# 299    26484
# Length: 300, dtype: int32

# %% [markdown]
# # Question 4

# %% [markdown]
# Wind Statistics

# %% [markdown]
# #### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# #### Step 2. Import the dataset from this address

# %% [markdown]
# #### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data', sep='\s+', parse_dates={'Date':["Yr","Mo","Dy"]}, keep_date_col=True)
data
# Source: https://cmdlinetips.com/2021/02/combine-year-month-and-day-columns-to-single-date-in-pandas/
# Out:
#            Date  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# 0    2061-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1    2061-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 2    2061-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 3    2061-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 4    2061-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...         ...  ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 6570 1978-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 6571 1978-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 6572 1978-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 6573 1978-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#         CLA    MUL    CLO    BEL    MAL
# ...

# %% [markdown]
# #### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it

# %%
data["Date"] = np.where(pd.DatetimeIndex(data["Date"]).year < 2021,
                        data.Date,data.Date - pd.offsets.DateOffset(years=100))
data
# Out:
#            Date  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# 0    1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1    1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 2    1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 3    1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 4    1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...         ...  ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 6570 1978-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 6571 1978-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 6572 1978-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 6573 1978-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#         CLA    MUL    CLO    BEL    MAL
# ...

# %% [markdown]
# #### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.dtypes
# Out:
# Date    datetime64[ns]
# Yr              object
# Mo              object
# Dy              object
# RPT            float64
# VAL            float64
# ROS            float64
# KIL            float64
# SHA            float64
# BIR            float64
# DUB            float64
# CLA            float64
# MUL            float64
# CLO            float64
# BEL            float64
# MAL            float64
# dtype: object

# %%
#index data based on the datatime column created
data = data.set_index('Date')
data
# Out:
#             Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# Date
# 1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...         ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 1978-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 1978-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 1978-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 1978-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#               CLA    MUL    CLO    BEL    MAL
# Date
# ...

# %% [markdown]
# #### Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below

# %%
data.isnull().sum().sum()
# Out:
# 31

# %% [markdown]
# #### Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum().sum()
# Out:
# 98579

# %% [markdown]
# #### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times

# %%
MeanSpeed = data[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].mean()
MeanSpeed
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %% [markdown]
# A single number for the entire dataset

# %%
MeanSpeed.mean()  #mean of mean
# Out:
# 10.227982360836924

# %% [markdown]
# #### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
# A different set of numbers for each location

# %%
# choosing only location columns

NewData = data.loc[:,['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']]
NewData
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# ...

# %%
# DataFrame called loc_stats

loc_stats=NewData.describe()
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %%
#table showing only required data

loc_stats = loc_stats.loc[['min','max','mean','std'],:]   
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %% [markdown]
# #### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
# A different set of numbers for each day

# %%
day_stats = pd.DataFrame({'min':data.min(axis=1),'max':data.max(axis=1),'mean':data.mean(axis=1),'std':data.std(axis=1)})
day_stats
# Out:
#              min    max       mean       std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# #### Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.

# %% [markdown]
# #### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.resample('Y').mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# #### Step 13. Downsample the record to a monthly frequency for each location

# %%
data.resample('M').mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# #### Step 14. Downsample the record to a weekly frequency for each location

# %%
data.resample('W').mean()
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %% [markdown]
# #### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week
# (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %% [markdown]
# # Question 5

# %% [markdown]
# #### Step 1-4.
# 1. Import the necessary libraries.
# 2. Import the dataset from this address.
# 3. Assign it to a variable called chipo.
# 4. See the first 10 entries.

# %%
import pandas as pd
import numpy as np
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# #### Step 5. What is the number of observations in the dataset?

# %%
chipo.count(axis=0)
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %% [markdown]
# #### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# #### Step 7. Print the name of all the columns

# %%
chipo.columns.tolist()
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# #### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# #### Step 9-10
# 9. Which was the most-ordered item?
# 10. For the most-ordered item, how many items were ordered?

# %%
MostOrdered = chipo.groupby('item_name').agg({'quantity':'sum'})
MostOrdered = MostOrdered.sort_values('quantity', ascending=False)
MostOrdered.head(1)
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %% [markdown]
# #### Step 11. What was the most ordered item in the choice_description column?

# %%
MostChoice = chipo.groupby('choice_description').sum()
MostChoice = MostChoice.sort_values(['quantity'], ascending=False)
MostChoice.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# #### Step 12. How many items were orderd in total?

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# #### Step 13.

# %%
# Check the item price type

chipo.item_price.dtype
# Out:
# dtype('O')

# %%
# Create a lambda function and change the type of item price

chipo.item_price = chipo.item_price.apply(lambda x: float(x[1:-1]))

# %%
# Check the item price type

chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 14. How much was the revenue for the period in the dataset?

# %%
revenue = chipo['item_price'] * chipo['quantity']
print("Revenue for the period is: $",revenue.sum())
# Out:
# revenue for the period is: $ 39237.02

# %% [markdown]
# #### Step 15. How many orders were made in the period?

# %%
chipo.order_id.value_counts().count()   #will return count of unique orders
# Out:
# 1834

# %% [markdown]
# #### Step 16. What is the average revenue amount per order?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
AverageRevenue = chipo['revenue'].sum()/chipo['revenue'].count()
print("Average revenue for the period is: $",np.round(AverageRevenue,2))  #rounds of to 2 decimal places
# Out:
# Average revenue for the period is: $ 8.49

# %% [markdown]
# #### Step 17. How many different items are sold?

# %%
chipo.item_name.value_counts().count()
# Out:
# 50

# %% [markdown]
# # Question 6

# %% [markdown]
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend. Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\sharm\Dropbox\My PC (LAPTOP-UGLC0FVG)\Downloads\us-marriages-divorces-1867-2014.csv")
data
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
plt.plot(data.Year, data['Marriages'], label='Marriages')
plt.plot(data.Year, data['Divorces'], label='Divorces')

plt.title("Divorces and Marriages per capita in U.S. between 1867-2014",fontsize=16, color = 'Green') 
plt.ylabel(" Number of Marriages, Divorces", fontweight=800);
plt.xlabel("Year", fontweight=800)

plt.legend();

# %% [markdown]
# # Question 7

# %% [markdown]
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
df_years = data[(data.Year == 1900) | (data.Year == 1950) | (data.Year == 2000)]
columns_0 = df_years.drop(columns = ['Population','Marriages_per_1000','Divorces_per_1000'])
columns_1 = columns_0.set_index('Year')
columns_1
# Out:
#       Marriages  Divorces
# Year
# 1900   709000.0   56000.0
# 1950  1667000.0  385000.0
# 2000  2315000.0  944000.0

# %%
columns_1.plot.bar(figsize=(12,6))
plt.xlabel('Years', fontweight =600)
plt.ylabel('Number of Marriages and Divorces', fontweight =600)
plt.title('Number of Marriages V/S Divorces per capita between years 1900, 1950, and 2000',fontsize =16,color ='Green')
plt.legend()
plt.show()

# %% [markdown]
# # Question 8

# %% [markdown]
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
kill_data = pd.read_csv(r"C:\Users\sharm\Dropbox\My PC (LAPTOP-UGLC0FVG)\Downloads\actor_kill_counts.csv", index_col=0)
kill_data
# Out:
#                        Count
# Actor
# Arnold Schwarzenegger    369
# Chow Yun-Fat             295
# Clint Eastwood           207
# Clive Owen               194
# Dolph Lundgren           239
# Jet Li                   201
# Nicolas Cage             204
# Sylvester Stallone       267
# Tomisaburo Wakayama      226
# Wesley Snipes            193

# %%
colours = ['Red','Green','Blue','Yellow','Pink','#C06C84','#6C5B7B','#355C7D','#9CA54B','Cyan']
kill_data['Count'].sort_values(ascending=True).plot.barh(color=colours,figsize=(10,5))

plt.title('Deadliest actors in Hollywood', fontsize=16)

plt.xlabel('Kill Count', fontweight=600)
plt.ylabel('Actor name',fontweight=600)


plt.show()

# %% [markdown]
# # Question 9

# %% [markdown]
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
roman_emperors = pd.read_csv(r"C:\Users\sharm\Dropbox\My PC (LAPTOP-UGLC0FVG)\Downloads\roman-emperor-reigns.csv")
death = pd.DataFrame({'count' : roman_emperors.groupby("Cause_of_Death" ).size()}).reset_index() 
labels = death['Cause_of_Death'].values
sizes = death['count'].values
explode=[y if item=='Assassinated' else x for item in labels ]
fig1, ax1 = plt.subplots(figsize=(14,10))
ax1.pie(sizes, autopct='%1.1f%%', startangle=90, textprops={'fontsize':12})
ax1.axis('equal')  
plt.legend(labels, loc="lower right", fontsize = 10)
plt.show()

# %% [markdown]
# # Question 10

# %% [markdown]
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
revenue = pd.read_csv(r"C:\Users\sharm\Dropbox\My PC (LAPTOP-UGLC0FVG)\Downloads\arcade-revenue-vs-cs-doctorates.csv")
revenue
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
sns.scatterplot(x='Total Arcade Revenue (billions)', 
                y='Computer Science Doctorates Awarded (US)', 
                hue='Year', 
                data=revenue).set_title('Total Arcade Revenue and Computer Science Doctorates Awarded (US) between 2000 and 2009\n', fontweight=600)
# Out:
# Text(0.5, 1.0, 'Total Arcade Revenue and Computer Science Doctorates Awarded (US) between 2000 and 2009\n')
